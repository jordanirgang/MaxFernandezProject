# %% [markdown]
# # Lecture 5
#
# Chapter 4 is last exam after midterm
#
# need common normal to be written
#
# new X needs to be a common normal
#
# new axis cannot cross over
# axsi needs to stay perpendicular to
#
# Fowards kinematics
# $$ \vec q \implies ^0T_{n} (\vec q) $$
# inverse kinematics
# $$ ^0T_n(\vec q) \implies \vec q $$
#
#
# $$ ^0T_{n}  = ^0T_{1} + ^1T_{2} + ... + ^{n-1}T_{n}  $$
# how do I get q_i ?
# some fucnction o everything
#
# $$ q_i = f_i(r_11,...,r_33, P_x, P_y,P_z) $$
# $$q_2 = 3r_11 + p_x $$
# So joint angles are non linear trancendentals
# Existence Uniqueness
#
# Workspace is a volume of space in which the volume of the end effector can reach
#
# Dexerouse workspace:
# reach all possble orientations
#
# vs
#
# Reachable oreintation atleast one orentation
#
# $$ \{Dexterouse\ workspace\} \subset \{reachable\ workspace\} $$
#
# \# of Dofs
# - usually n, not always
#
# \# of uknowns
# -
#
# if \# of DOFs = \# of eqns,
# you have a unique or finite number of soltions
# if \# of DOFs < \# of eqns,
# sln may not exist
# if \# of DOFs > \# of eqns,
# possible infintite slns
#
# $$ x = a_1 cos \theta_1 + a_2 cos(\theta_1 + \theta_2) $$
# $$ y = a_1 sin \theta_1 + a_2 sin(\theta_1 + \theta_2) $$
# $$ q_1 = \theta_1 $$
# $$ q_2 = \theta_2 $$
# get as close as you can with inverse kinematics to get optimal solution, as solution might not exist
#
# can only have 6 eqns
# can add more equations based on looking at oreintation of other then end effector
#
#
# ## Analytic vs numerical slns
# numerical is iterative

# %%
import math
def iterative_sqrt_2(s):
    return (s+2/s)/2

a = iterative_sqrt_2(1.5)
display(a)

for i in range (1,20):
    a = iterative_sqrt_2(a)
    display(a)
display("ans")
display(math.sqrt(2))
# Out:
# 1.4166666666666665
# 1.4142156862745097
# 1.4142135623746899
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 1.414213562373095
# 'ans'
# 1.4142135623730951

# %% [markdown]
# should do course in numerical methods
# ### Bisections
#
# ### secant method
# ### newton-raphson
# derivative based

# %% [markdown]
# Always use A tan2 for quadrant
#
# Wirestrauss substitution(middle of 4-2

# %%
import time

import mujoco
import mujoco.viewer

m = mujoco.MjModel.from_xml_path('/home/yukimi/Jupyter/Mechatronics/Notes/mjcf.urdf')
d = mujoco.MjData(m)

with mujoco.viewer.launch_passive(m, d) as viewer:
  # Close the viewer automatically after 30 wall-seconds.
  start = time.time()
  while viewer.is_running() and time.time() - start < 30:
    step_start = time.time()

    # mj_step can be replaced with code that also evaluates
    # a policy and applies a control signal before stepping the physics.
    mujoco.mj_step(m, d)

    # Example modification of a viewer option: toggle contact points every two seconds.
    with viewer.lock():
      viewer.opt.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = int(d.time % 2)

    # Pick up changes to the physics state, apply perturbations, update options from GUI.
    viewer.sync()

    # Rudimentary time keeping, will drift relative to wall clock.
    time_until_next_step = m.opt.timestep - (time.time() - step_start)
    if time_until_next_step > 0:
      time.sleep(time_until_next_step)
