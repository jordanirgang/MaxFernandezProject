# %% [markdown]
# ## Equations of motion for X,Y in respect to to angles
# $$c= T-L $$

# %%
import sympy as sp
from IPython.display import Math

potential, kinnetic = sp.symbols('T L')
sp.Eq (potential - kinnetic,
       sp.symbols('\mathcal{L}'))
# Out:
# Eq(-L + T, \mathcal{L})

# %%
time = sp.symbols('t')

angle_1= sp.Function('theta_1')(time)
angle_2= sp.Function('theta_2')(time)


length_1 , length_2 = sp.symbols('a_1 a_2')

display(
    sp.Derivative(sp.cos(angle_
                         1), angle_1)
       )

sp.simplify(
    sp.Derivative(length_1*sp.cos(angle_1+angle_2 ), time
                         ))
# Out:
# Derivative(cos(theta_1(t)), theta_1(t))
# -a_1*(Derivative(theta_1(t), t) + Derivative(theta_2(t), t))*sin(theta_1(t) + theta_2(t))

# %%
x = length_1 * sp.cos(angle_1) + length_2 * sp.cos(angle_1 + angle_2)
y = length_1 * sp.sin(angle_1) + length_2 * sp.sin(angle_1 + angle_2)
sp.init_printing(use_unicode=True)
x_sym,y_sym,x_dot_sym,y_dot_sym = sp.symbols('x y {x02D9} {\doty}')

x_dot = sp.Derivative(x,time)
y_dot = sp.Derivative(y,time)







sp.simplify(sp.Matrix([
    [sp.atan2(y,x),
    sp.atan2(y_dot,x_dot)]
    ]).T)

#sp.Matrix([[x_sym,y_sym,x_dot_sym,y_dot_sym]])
# Out:
# ⎡                                   atan2(a₁⋅sin(θ₁(t)) + a₂⋅sin(θ₁(t) + θ₂(t) ↪
# ⎢                                                                              ↪
# ⎢     ⎛              d              ⎛d           d        ⎞                    ↪
# ⎢atan2⎜a₁⋅cos(θ₁(t))⋅──(θ₁(t)) + a₂⋅⎜──(θ₁(t)) + ──(θ₂(t))⎟⋅cos(θ₁(t) + θ₂(t)) ↪
# ⎣     ⎝              dt             ⎝dt          dt       ⎠                    ↪
#
# ↪ ), a₁⋅cos(θ₁(t)) + a₂⋅cos(θ₁(t) + θ₂(t)))                                    ↪
# ↪                                                                              ↪
# ↪                   d              ⎛d           d        ⎞                   ⎞ ↪
# ↪ , - a₁⋅sin(θ₁(t))⋅──(θ₁(t)) - a₂⋅⎜──(θ₁(t)) + ──(θ₂(t))⎟⋅sin(θ₁(t) + θ₂(t))⎟ ↪
# ↪                   dt             ⎝dt          dt       ⎠                   ⎠ ↪
#
# ↪ ⎤
# ↪ ⎥
# ↪ ⎥
# ↪ ⎥
# ↪ ⎦
