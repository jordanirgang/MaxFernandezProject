# %%
import sympy as sp
potential, kinnetic = sp.symbols('T L')
sp.Eq (potential - kinnetic,
       sp.symbols('/Lagr'))
# Out:
# Eq(-L + T, /Lagr)

# %%
angle_1, angle_2= sp.symbols('theta_1 theta_2')
length_1 , length_2 = sp.symbols('a_1 a_2')
display(
    sp.Derivative(sp.cos(angle_1), angle_1)
       )
sp.simplify(sp.Derivative(length_1*
                          sp.cos(angle_1+angle_2
                                ), angle_1
                         
                         ))
# Out:
# Derivative(cos(theta_1), theta_1)
# -a_1*sin(theta_1 + theta_2)
